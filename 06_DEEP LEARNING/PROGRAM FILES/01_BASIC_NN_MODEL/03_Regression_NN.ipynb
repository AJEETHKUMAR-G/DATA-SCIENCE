# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in e:\program_files_x86\anaconda\envs\tf_env\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------- ----------------------------- 2.4/8.9 MB 11.2 MB/s eta 0:00:01
#    --------------------- ------------------ 4.7/8.9 MB 11.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.8/8.9 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 10.6 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/41.3 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/41.3 MB 11.4 MB/s eta 0:00:04
#    ------ --------------------------------- 7.1/41.3 MB 11.5 MB/s eta 0:00:03
#    --------- ------------------------------ 9.7/41.3 MB 11.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.1/41.3 MB 11.6 MB/s eta 0:00:03
#    ------------- -------------------------- 14.4/41.3 MB 11.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 17.0/41.3 MB 11.7 MB/s eta 0:00:03
#    ------------------ --------------------- 19.4/41.3 MB 11.7 MB/s eta 0:00:02
#    -------------------- ------------------- 20.7/41.3 MB 11.1 MB/s eta 0:00:02
#    --------------------- ------------------ 22.3/41.3 MB 10.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 24.4/41.3 MB 10.6 MB/s eta 0:00:02
#    ------------------------- -------------- 26.5/41.3 MB 10.6 MB/s eta 0:00:02
#    --------------------------- ------------ 28.8/41.3 MB 10.7 MB/s eta 0:00:02
#    ------------------------------ --------- 31.5/41.3 MB 10.8 MB/s eta 0:00:01
#    -------------------------------- ------- 33.8/41.3 MB 10.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.2/41.3 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 38.5/41.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.3 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 MB 10.7 MB/s  0:00:03
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.boston_housing.load_data()

# %%
X_train.shape
# Out:
# (404, 13)

# %%
X_test.shape
# Out:
# (102, 13)

# %%
X_train[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)  # y - mx+b | act_func = linear
])
# Out:
# WARNING:tensorflow:From E:\PROGRAM_FILES_x86\ANACONDA\envs\tf_env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)
# Out:
# WARNING:tensorflow:From E:\PROGRAM_FILES_x86\ANACONDA\envs\tf_env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 26/26 [==============================] - 3s 6ms/step - loss: 543.2117 - mae: 21.4533
# Epoch 2/50
# 26/26 [==============================] - 0s 5ms/step - loss: 440.1091 - mae: 18.9706
# Epoch 3/50
# 26/26 [==============================] - 0s 6ms/step - loss: 287.0817 - mae: 14.7843
# Epoch 4/50
# 26/26 [==============================] - 0s 5ms/step - loss: 132.5796 - mae: 9.3351
# Epoch 5/50
# 26/26 [==============================] - 0s 5ms/step - loss: 64.2999 - mae: 6.1821
# Epoch 6/50
# 26/26 [==============================] - 0s 5ms/step - loss: 40.7548 - mae: 4.7425
# Epoch 7/50
# 26/26 [==============================] - 0s 5ms/step - loss: 29.2501 - mae: 3.9737
# Epoch 8/50
# 26/26 [==============================] - 0s 5ms/step - loss: 24.4235 - mae: 3.6102
# Epoch 9/50
# 26/26 [==============================] - 0s 5ms/step - loss: 21.0961 - mae: 3.3079
# Epoch 10/50
# 26/26 [==============================] - 0s 5ms/step - loss: 19.4845 - mae: 3.1522
# Epoch 11/50
# 26/26 [==============================] - 0s 6ms/step - loss: 18.1983 - mae: 3.0510
# Epoch 12/50
# 26/26 [==============================] - 0s 5ms/step - loss: 17.1124 - mae: 2.9624
# Epoch 13/50
# 26/26 [==============================] - 0s 8ms/step - loss: 16.1785 - mae: 2.8936
# Epoch 14/50
# 26/26 [==============================] - 0s 5ms/step - loss: 15.4680 - mae: 2.8212
# Epoch 15/50
# 26/26 [==============================] - 0s 6ms/step - loss: 14.9249 - mae: 2.7687
# Epoch 16/50
# 26/26 [==============================] - 0s 5ms/step - loss: 14.3259 - mae: 2.7107
# Epoch 17/50
# 26/26 [==============================] - 0s 5ms/step - loss: 13.7148 - mae: 2.6385
# Epoch 18/50
# 26/26 [==============================] - 0s 5ms/step - loss: 13.2119 - mae: 2.6155
# Epoch 19/50
# 26/26 [==============================] - 0s 5ms/step - loss: 12.7747 - mae: 2.5580
# Epoch 20/50
# 26/26 [==============================] - 0s 5ms/step - loss: 12.4333 - mae: 2.5143
# Epoch 21/50
# 26/26 [==============================] - 0s 5ms/step - loss: 12.3837 - mae: 2.5399
# Epoch 22/50
# 26/26 [==============================] - 0s 5ms/step - loss: 11.8784 - mae: 2.4644
# Epoch 23/50
# 26/26 [==============================] - 0s 5ms/step - loss: 11.5981 - mae: 2.4640
# Epoch 24/50
# 26/26 [==============================] - 0s 6ms/step - loss: 11.5291 - mae: 2.4236
# Epoch 25/50
# 26/26 [==============================] - 0s 5ms/step - loss: 11.2595 - mae: 2.4300
# Epoch 26/50
# 26/26 [==============================] - 0s 5ms/step - loss: 10.8556 - mae: 2.3711
# Epoch 27/50
# 26/26 [==============================] - 0s 6ms/step - loss: 10.8451 - mae: 2.3740
# Epoch 28/50
# 26/26 [==============================] - 0s 6ms/step - loss: 10.8262 - mae: 2.3910
# Epoch 29/50
# 26/26 [==============================] - 0s 5ms/step - loss: 10.3167 - mae: 2.3200
# Epoch 30/50
# 26/26 [==============================] - 0s 5ms/step - loss: 10.3962 - mae: 2.3478
# Epoch 31/50
# 26/26 [==============================] - 0s 6ms/step - loss: 10.2469 - mae: 2.3016
# Epoch 32/50
# 26/26 [==============================] - 0s 5ms/step - loss: 10.1053 - mae: 2.3045
# Epoch 33/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.9222 - mae: 2.2766
# Epoch 34/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.6971 - mae: 2.2706
# Epoch 35/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.9579 - mae: 2.2773
# Epoch 36/50
# 26/26 [==============================] - 0s 5ms/step - loss: 10.3270 - mae: 2.3730
# Epoch 37/50
# 26/26 [==============================] - 0s 6ms/step - loss: 9.4402 - mae: 2.2233
# Epoch 38/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.5048 - mae: 2.2485
# Epoch 39/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.2381 - mae: 2.2110
# Epoch 40/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.1796 - mae: 2.2296
# Epoch 41/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.1974 - mae: 2.1828
# Epoch 42/50
# 26/26 [==============================] - 0s 5ms/step - loss: 9.1827 - mae: 2.1938
# Epoch 43/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.8484 - mae: 2.1823
# Epoch 44/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.9485 - mae: 2.1694
# Epoch 45/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.8720 - mae: 2.1747
# Epoch 46/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.7435 - mae: 2.1626
# Epoch 47/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.6435 - mae: 2.1556
# Epoch 48/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.6823 - mae: 2.1232
# Epoch 49/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.5689 - mae: 2.1555
# Epoch 50/50
# 26/26 [==============================] - 0s 5ms/step - loss: 8.5277 - mae: 2.1066

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 8ms/step - loss: 21.3086 - mae: 3.0040
# [21.3085994720459, 3.0040156841278076]
